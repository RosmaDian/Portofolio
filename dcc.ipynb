# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set(font_scale=1.0)

# %%
#Impor data
df = pd.read_csv('/e.csv')
diff_watch = df['days_diff_reg_watch']
diff_purch = df['days_diff_watch_purch']

# %%
#Cleaning data
diff_watch.dropna()
diff_purch.dropna()
# Out:
# 7         1.0
# 16       54.0
# 23       27.0
# 32        1.0
# 46        4.0
#          ...
# 19014    25.0
# 19015     1.0
# 19071    26.0
# 19072     1.0
# 19110    26.0
# Name: days_diff_watch_purch, Length: 1158, dtype: float64

# %%
#Data Deskription
diff_watch.describe()
diff_purch.describe()
# Out:
# count    1158.000000
# mean       51.814335
# std        93.517274
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        53.000000
# max       573.000000
# Name: days_diff_watch_purch, dtype: float64

# %%
#Data Visualization
sns.kdeplot(data = diff_watch)
sns.kdeplot(data = diff_purch)
# Out:
# <Axes: xlabel='days_diff_reg_watch', ylabel='Density'>
